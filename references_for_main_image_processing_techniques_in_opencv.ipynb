# %% [markdown]
# <a href="https://colab.research.google.com/github/albertofernandezvillan/computer-vision-and-deep-learning-course/blob/main/references_for_main_image_processing_techniques_in_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" style="padding-right:10px;" src ="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/university_oviedo_logo.png" width=300 px>
#
# This notebook is from the Course "***Computer vision in the new era of Artificial Intelligence and Deep Learning***", or "*Visión por computador en la nueva era de la Inteligencia Artificial y el Deep Learning*" (ES) from the "Second quarter university extension courses" that the University of Oviedo is offering (05/04/2021 - 16/04/2021)
#
# <[Github Repository](https://github.com/albertofernandezvillan/computer-vision-and-deep-learning-course) | [Course Web Page Information](https://www.uniovi.es/estudios/extension/cursos2c/-/asset_publisher/SEp0PJi4ISGo/content/vision-por-computador-en-la-nueva-era-de-la-inteligencia-artificial-y-el-deep-learning?redirect=%2Festudios%2Fextension%2Fcursos2c)>

# %% [markdown]
# # Summary
#
# In this Notebook, a collection of references to both Python scripts and notebooks will be given in connection with image processing in OpenCV and Python. All of this references are from the book "[Mastering OpenCV 4 with Python](https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python)" and also from [the repository of this notebook](https://github.com/albertofernandezvillan/computer-vision-and-deep-learning-course).
#
# <img align="left" src ="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/icon_book.png" width=50 px>
#
# *Villán, A. F. (2019). **Mastering OpenCV 4 with Python: a practical guide covering topics from image processing, augmented reality to deep learning with OpenCV 4 and Python 3.7**. Packt Publishing Ltd.*
#
# The following topics will be covered:
# *   Image Basics in OpenCV
# *   Handling Files and Images
# *   Constructing Basic Shapes in OpenCV
# *   Image Processing Techniques
# *   Constructing and Building Histograms
# *   Thresholding Techniques
# *   Contours Detection, Filtering, and Drawing
# *   Augmented Reality

# %% [markdown]
# # Image Basics in OpenCV
# ---
#
# ***Accessing, manipulating pixels in OpenCV with both color and grayscale images***
#
# *   https://github.com/albertofernandezvillan/computer-vision-and-deep-learning-course/blob/main/basic_image_treatment_with_opencv.ipynb
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter02/01-chapter-content/01_getting_and_setting_bgr.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter02/01-chapter-content/02_getting_and_setting_gray.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/01_image_basics_02.png" border="5px solid" width="500">
#
# ---
#
# ***Showing images with both OpenCV and Matplotlib***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter02/01-chapter-content/03_displaying_images.py
#
# ---
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/02_image_basics_01.png" class="center" border="5px solid" width="700">
#
# ---

# %% [markdown]
# # Handling Files and Images
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/03_handling_files_and_images_01.png" border="5px solid" width="500">
#
#
# ---
#
# ***How to load and save images using argparse:***
# *    https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter03/01-chapter-content/argparse_load_processing_save_image.py
# ---
#
# ***How to read a camera connected to your computer and show FPS***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter03/01-chapter-content/read_camera_fps.py
#  ---
#
# ***How to read a video file and get all properties:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter03/01-chapter-content/read_video_file_all_properties.py
# ---
# ***How to read a video file backwards:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter03/01-chapter-content/read_video_file_backwards.py
# ---
# ***How to write a video file:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter03/01-chapter-content/write_video_file.py
# ---

# %% [markdown]
# # Constructing Basic Shapes in OpenCV
#
# ---
# ***Testing predefined colors and matplotlib output:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter04/01-chapter-content/testing_colors.py
# ---
#
# ***Example to show the lineType argument in OpenCV (when showing lines):***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter04/01-chapter-content/basic_line_types.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/04_line_type.png" border="5px solid" width="400">
#
# ---
#
# ***Drawing basic figures (points, lines, poligonal curves,...) in OpenCV:***
# *   https://github.com/albertofernandezvillan/computer-vision-and-deep-learning-course/blob/main/basic_drawing_opencv.ipynb
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter04/01-chapter-content/basic_drawing.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter04/01-chapter-content/basic_drawing_2.py
# ---
#
# ***Drawing text and symbols in OpenCV:***
# *   https://github.com/albertofernandezvillan/computer-vision-and-deep-learning-course/blob/main/drawing_text_and_symbols_in_opencv.ipynb
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter04/01-chapter-content/text_drawing.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter04/01-chapter-content/text_drawing_fonts.py
# ---
#
# ***How to draw text and a bounding box adapted to the text size:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter04/01-chapter-content/text_drawing_bounding_box.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/05_get_text_size.png" border="5px solid" width="700">
#
# ---
# ***Example to show how to draw an analog clock using drawing primitives in OpenCV:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter04/01-chapter-content/analog_clock_opencv.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/06_analog_clock.png" border="5px solid" width="500">
#
# ---

# %% [markdown]
# # Image Processing Techniques
# ---
# ***Comparing different methods for smoothing images:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/smoothing_techniques.py
# ---
#
# ***Comparing different methods for sharpening images:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/sharpening_techniques.py
# ---
#
# ***Arithmetic with images (add/subtract a intensity value to every pixel in the image):***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/arithmetic.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/07_arithmetic_with_images.png" border="5px solid" width="500">
#
# ---
# ***Bitwise operations (AND, OR, XOR, NOT):***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/bitwise_operations.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/bitwise_operations_images.py
# ---
#
# ***Morphological operations (erode, dilate, opening, closing, ...):***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/morphological_operations.py
#
# <img src"https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/08_morphological_operations.png" border="5px solid" width="700">
#
# ---
# ***Introduction to color spaces in OpenCV:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/color_spaces.py
# ---
#
# ***Skin segmentation algorithms based on different color spaces:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/skin_segmentation.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/09_skin_detection.png" border="5px solid" width="700">
#
# ---
#
# ***Example for testing all colors maps in OpenCV:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/color_map_all.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/10_colormaps.png" border="5px solid" width="700">
#
# ---
# ***Geometric image transformations in OpenCV:***
# *   https://github.com/albertofernandezvillan/dl-ml-notebooks/blob/main/geometric_image_transformations_opencv.ipynb
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter05/01-chapter-content/geometric_image_transformations.py
# ---
#
# ***OpenCV sliders for image processing:***
# *  https://github.com/albertofernandezvillan/dl-ml-notebooks/blob/main/opencv_sliders_introduction_image_processing.ipynb
# ---
#
# ***Computational photography module in OpenCV:***
# *   https://github.com/albertofernandezvillan/dl-ml-notebooks/blob/main/computational_photography_module_opencv.ipynb
# ---
#
# ***Inpainting with OpenCV:***
# *   https://github.com/albertofernandezvillan/dl-ml-notebooks/blob/main/inpaint_algorithm_in_opencv.ipynb
# ---
#
# ***K-means clustering for color quantization with OpenCV:***
# *   https://github.com/albertofernandezvillan/dl-ml-notebooks/blob/main/k_means_clustering_opencv.ipynb
# ---

# %% [markdown]
# # Constructing and Building Histograms
# ---
# ***Grayscale histograms:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/histogram_introduction.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/11_grayscale_histogram_introduction.png" border="5px solid" width="600">
#
# ---
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/grayscale_histogram.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/12_grayscale_histogram.png" border="5px solid" width="600">
#
# ---
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/grayscale_histogram_mask.py
# ---
#
# ***Color histograms:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/color_histogram.py
# ---
#
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/histogram_custom_visualization.py
# ---
#
# ***Comparing how to create histograms using OpenCV, numpy and matplotlib:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/comparing_opencv_numpy_mpl_hist.py
# ---
#
# ***Introduction to grayscale histogram equalization:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/grayscale_histogram_equalization.py
# ---
#
# ***Color histogram equalization using the HSV color space:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/color_histogram_equalization_hsv.py
# ---
#
# ***Histogram equalization using CLAHE:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/comparing_hist_equalization_clahe.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/clahe_histogram_equalization.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/13_clahe.png" border="5px solid" width="700">
#
# ---
# ***Grayscale histogram comparison:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter06/01-chapter-content/compare_histograms.py
# ---

# %% [markdown]
# # Thresholding Techniques
# ---
# ***Introduction to thresholding:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter07/01-chapter-content/thresholding_introduction.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/14_thresholding_introduction.png" border="5px solid" width="300">
#
# ---
# ***Adaptive thresholding:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter07/01-chapter-content/thresholding_adaptive.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter07/01-chapter-content/thresholding_adaptive_filter_noise.py
# ---
#
# ***Otsu's binarization algorithm:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter07/01-chapter-content/thresholding_otsu.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter07/01-chapter-content/thresholding_otsu_filter_noise.py
# ---
#
# ***Triangle thresholding:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter07/01-chapter-content/thresholding_triangle_filter_noise.py
# ---
#
# ***Thresholding techniques using scikit-image library:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter07/01-chapter-content/thresholding_scikit_image_techniques.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/15_thresholding_scikit_image.png" border="5px solid" width="600">
#
# ---

# %% [markdown]
# # Contours Detection, Filtering, and Drawing
# ---
# ***Introduction to contours in OpenCV:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_introduction.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_introduction_2.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/16_contours_introduction.png" border="5px solid" width="700">
#
# ---
# ***Contours analysis based mainly on moments:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_analysis.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_ellipses.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/17_eccentricity.png" border="5px solid" width="700">
#
# ---
# ***Hu moments in OpenCV:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_hu_moments.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_hu_moments_properties.py
# ---
#
# ***OpenCV functionality related to contours:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_functionality.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/18_functionality_related_to_contours.png" border="5px solid" width="600">
#
# ---
# ***Ordering contours based on the size:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_short_size.py
# ---
#
# ***Contours shape recognition mainly based on cv2.approxPolyDP() function:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_shape_recognition.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/19_shape_recognition.png" border="5px solid" width="600">
#
# ---
# ***Matching contours using cv2.matchShapes() against a perfect circle:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter08/01-chapter-content/contours_matching.py
# ---

# %% [markdown]
# # Augmented Reality
# ---
# ***Snapchat-based augmented reality OpenCV filters:***
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter09/01-chapter-content/snapchat_augmeted_reality_moustache.py
# *   https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python/blob/master/Chapter09/01-chapter-content/snapchat_augmeted_reality_glasses.py
#
# <img src="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/image_processing/20_snapchat_based_filter_glasses.png" border="5px solid" width="500">
#
# ---

# %% [markdown]
# # Conclusions
#
# In this Notebook, a collection of references to both Python scripts and notebooks was given in connection with image processing in OpenCV and Python.
#
# All of this references are from the book "[Mastering OpenCV 4 with Python](https://github.com/PacktPublishing/Mastering-OpenCV-4-with-Python)" and also from [the repository of this notebook](https://github.com/albertofernandezvillan/computer-vision-and-deep-learning-course).
#
# <img align="left" src ="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/icon_book.png" width=50 px>
#
# *Villán, A. F. (2019). **Mastering OpenCV 4 with Python: a practical guide covering topics from image processing, augmented reality to deep learning with OpenCV 4 and Python 3.7**. Packt Publishing Ltd.*
