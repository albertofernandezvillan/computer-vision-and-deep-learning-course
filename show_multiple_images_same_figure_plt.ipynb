# %% [markdown]
# <a href="https://colab.research.google.com/github/albertofernandezvillan/computer-vision-and-deep-learning-course/blob/main/show_multiple_images_same_figure_plt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" style="padding-right:10px;" src ="https://raw.githubusercontent.com/albertofernandezvillan/computer-vision-and-deep-learning-course/main/assets/university_oviedo_logo.png" width=300 px>
#
# This notebook is from the Course "***Computer vision in the new era of Artificial Intelligence and Deep Learning***", or "*Visión por computador en la nueva era de la Inteligencia Artificial y el Deep Learning*" (ES) from the "Second quarter university extension courses" that the University of Oviedo is offering (05/04/2021 - 16/04/2021)
#
# <[Github Repository](https://github.com/albertofernandezvillan/computer-vision-and-deep-learning-course) | [Course Web Page Information](https://www.uniovi.es/estudios/extension/cursos2c/-/asset_publisher/SEp0PJi4ISGo/content/vision-por-computador-en-la-nueva-era-de-la-inteligencia-artificial-y-el-deep-learning?redirect=%2Festudios%2Fextension%2Fcursos2c)>

# %% [markdown]
# # Summary
#
# In this notebook, we are introducing a utility function to show multi images in the same figure using matplotlib. In this sense, the function `show_img_plt(img, is_color=True, title="", show_axis=True, n_rows=1, n_cols=1, pos=1)` is coded. To test it, we are going to download a sample image from the OpenCV repository.

# %% [markdown]
# # Download the sample image

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/samples/data/HappyFish.jpg
# Out:
# --2021-03-07 13:45:25--  https://raw.githubusercontent.com/opencv/opencv/master/samples/data/HappyFish.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8283 (8.1K) [image/jpeg]
# Saving to: ‘HappyFish.jpg’
#
# HappyFish.jpg       100%[===================>]   8.09K  --.-KB/s    in 0s
#
# 2021-03-07 13:45:25 (40.3 MB/s) - ‘HappyFish.jpg’ saved [8283/8283]

# %% [markdown]
# # Coding the function `show_img_plt()`

# %%
from matplotlib import pyplot as plt
import cv2


def show_img_plt(img, is_color=True, title="", show_axis=True, n_rows=1, n_cols=1, pos=1):
    """Shows an image using matplotlib capabilities"""

    if is_color:
      # Convert BGR image to RGB
      img_rgb = img[:, :, ::-1]
    else:
      # We convert the image from gray to BGR
      img_rgb = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

    ax = plt.subplot(n_rows, n_cols, pos)
    plt.imshow(img_rgb)
    plt.title(title)
    if show_axis is False:
      plt.axis('off')

# %% [markdown]
# # Testing the function `show_img_plt()`

# %%
img_bgr = cv2.imread("/content/HappyFish.jpg")
print("Loaded image with shape: '{}'".format(img_bgr.shape))
# Out:
# Loaded image with shape: '(194, 259, 3)'

# %%
img_gray = cv2.imread("/content/HappyFish.jpg", cv2.IMREAD_GRAYSCALE)
print("Loaded image with shape: '{}'".format(img_gray.shape))
# Out:
# Loaded image with shape: '(194, 259)'

# %%
# Create the dimensions of the figure and set title:
plt.figure(figsize=(6, 4))
plt.suptitle("Testing visualization", fontsize=14, fontweight='bold')

show_img_plt(img_bgr)

# Show the created image:
plt.show()

# %%
# Create the dimensions of the figure and set title:
plt.figure(figsize=(6, 4))
plt.suptitle("Testing visualization", fontsize=14, fontweight='bold')

show_img_plt(img_gray, is_color=False, title='gray image')

# Show the created image:
plt.show()

# %%
# Create the dimensions of the figure and set title:
plt.figure(figsize=(10, 4))
plt.suptitle("Testing visualization", fontsize=14, fontweight='bold')

show_img_plt(img_bgr, is_color=True, title='color image', show_axis=True, n_rows=1, n_cols=2, pos=1)
show_img_plt(img_gray, is_color=False, title='gray image', show_axis=False, n_rows=1, n_cols=2, pos=2)

# Show the created image:
plt.show()

# %% [markdown]
# `cv2.flip()` can be used to flip images. In this sense, The image is flipped according to the value of flipCode as follows:
# *   `flipcode = 0`: flip vertically
# *   `flipcode > 0`: flip horizontally
# *   `flipcode < 0`: flip vertically and horizontally

# %%
# Generate six new images to show.
img_bgr_flip_ud = cv2.flip(img_bgr, 0)
img_bgr_flip_lr = cv2.flip(img_bgr, 1)
img_bgr_flip_ud_lr = cv2.flip(img_bgr, -1)

img_gray_flip_ud = cv2.flip(img_gray, 0)
img_gray_flip_lr = cv2.flip(img_gray, 1)
img_gray_flip_ud_lr = cv2.flip(img_gray, -1)

# Create the dimensions of the figure and set title:
plt.figure(figsize=(12, 7))
plt.suptitle("Testing visualization (and flipping)", fontsize=14, fontweight='bold')

show_img_plt(img_bgr_flip_ud, title='flip ud', n_rows=2, n_cols=3, pos=1)
show_img_plt(img_bgr_flip_lr, title='flip lr', n_rows=2, n_cols=3, pos=2)
show_img_plt(img_bgr_flip_ud_lr, title='flip ud lr', n_rows=2, n_cols=3, pos=3)

show_img_plt(img_gray_flip_ud, is_color=False, title='flip ud', n_rows=2, n_cols=3, pos=4)
show_img_plt(img_gray_flip_lr, is_color=False, title='flip lr', n_rows=2, n_cols=3, pos=5)
show_img_plt(img_gray_flip_ud_lr, is_color=False, title='flip ud lr', n_rows=2, n_cols=3, pos=6)

# Show the created image:
plt.show()

# %% [markdown]
# # Conclusions
#
# In this notebook we have introduced function `show_img_plt(img, is_color=True, title="", show_axis=True, n_rows=1, n_cols=1, pos=1)`, which can be used to show several images in the same matplotlib figure.
#
# Moreover, we have also seen how to use `cv2.flip()`, which can be used to flip images. For more information about flip and rotate [you can check this post](https://note.nkmk.me/en/python-opencv-numpy-rotate-flip/).
